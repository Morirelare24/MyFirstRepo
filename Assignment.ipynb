# %% [markdown]
# <a href="https://colab.research.google.com/github/Morirelare24/MyFirstRepo/blob/main/Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = "Habeebah"
age = 25
country = "Nigeria"
print("Name:", name)
print("Age:", age)
print("Country:", country)
# Out:
# Name: Habeebah
# Age: 25
# Country: Nigeria

# %%
favorite_number = 7
square = favorite_number * favorite_number
print("Favorite Number:", favorite_number)
print("Square of the number:", square)
# Out:
# Favorite Number: 7
# Square of the number: 49

# %%
a = 5
b = 10
print("Before swapping:")
print("a =", a)
print("b =", b)
a, b = b, a
print("After swapping:")
print("a =", a)
print("b =", b)
# Out:
# Before swapping:
# a = 5
# b = 10
# After swapping:
# a = 10
# b = 5
